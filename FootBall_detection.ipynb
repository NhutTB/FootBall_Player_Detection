# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
import pyresearch

# %%
# Load the YOLO model
model = YOLO("Football2.pt")
names = model.model.names

# %%
cap = cv2.VideoCapture("demo1.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter("visioneye-pinpoint.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

center_point = (-10, h)

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0)
    boxes = results[0].boxes.xyxy.cpu()
    clss = results[0].boxes.cls.cpu().tolist()

    annotator = Annotator(im0, line_width=2)
    for box, cls in zip(boxes, clss):
        annotator.box_label(box, label=names[int(cls)], color=colors(int(cls)))
        annotator.visioneye(box, center_point)

    out.write(im0)
 
    display_width = 1080
    display_height = int((display_width / w) * h)
    im_display = cv2.resize(im0, (display_width, display_height))

    cv2.imshow("visioneye-pinpoint", im_display)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release resources
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 16 players, 79.1ms
# Speed: 4.6ms preprocess, 79.1ms inference, 374.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 18.9ms
# Speed: 0.0ms preprocess, 18.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 19.8ms
# Speed: 6.0ms preprocess, 19.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 24.7ms
# Speed: 4.1ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 26.0ms
# Speed: 0.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 13.9ms
# Speed: 7.5ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 25.7ms
# Speed: 0.5ms preprocess, 25.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 33.9ms
# Speed: 2.0ms preprocess, 33.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 22.7ms
# Speed: 0.0ms preprocess, 22.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 29.1ms
# Speed: 0.0ms preprocess, 29.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 29.7ms
# Speed: 0.0ms preprocess, 29.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 57.9ms
# Speed: 0.0ms preprocess, 57.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 26.9ms
# Speed: 3.4ms preprocess, 26.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 20.1ms
# Speed: 0.1ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 24.7ms
# Speed: 0.0ms preprocess, 24.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 19.1ms
# Speed: 10.0ms preprocess, 19.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 25.4ms
# Speed: 0.0ms preprocess, 25.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 17.5ms
# Speed: 8.3ms preprocess, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 34.1ms
# Speed: 10.1ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 17.6ms
# Speed: 5.0ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 23.2ms
# Speed: 10.0ms preprocess, 23.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 16.4ms
# Speed: 4.2ms preprocess, 16.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 19.4ms
# Speed: 4.0ms preprocess, 19.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 18.9ms
# Speed: 3.8ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 16.7ms
# Speed: 4.2ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 33.1ms
# Speed: 4.1ms preprocess, 33.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 18.8ms
# Speed: 0.0ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 18.4ms
# Speed: 0.0ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 17.5ms
# Speed: 4.0ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 18.7ms
# Speed: 3.8ms preprocess, 18.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 20.8ms
# Speed: 4.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 24.7ms
# Speed: 0.0ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 21.9ms
# Speed: 0.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 16.5ms
# Speed: 4.2ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 20.6ms
# Speed: 8.1ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 19.7ms
# Speed: 4.1ms preprocess, 19.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 15.8ms
# Speed: 3.8ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 16.7ms
# Speed: 4.2ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 17.7ms
# Speed: 3.9ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 20.8ms
# Speed: 4.1ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 20.8ms
# Speed: 4.0ms preprocess, 20.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 25.0ms
# Speed: 4.0ms preprocess, 25.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 20.9ms
# Speed: 4.4ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 20.8ms
# Speed: 4.7ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 21.9ms
# Speed: 0.0ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 19.7ms
# Speed: 4.1ms preprocess, 19.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 20.0ms
# Speed: 3.9ms preprocess, 20.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 23.2ms
# Speed: 2.1ms preprocess, 23.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 19.5ms
# Speed: 3.6ms preprocess, 19.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 22.5ms
# Speed: 4.1ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 23.2ms
# Speed: 0.0ms preprocess, 23.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 22.0ms
# Speed: 3.6ms preprocess, 22.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 17.3ms
# Speed: 4.3ms preprocess, 17.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 16.3ms
# Speed: 4.1ms preprocess, 16.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 34.5ms
# Speed: 0.0ms preprocess, 34.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 25.0ms
# Speed: 3.9ms preprocess, 25.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 26.6ms
# Speed: 0.0ms preprocess, 26.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 24.5ms
# Speed: 4.2ms preprocess, 24.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 22.8ms
# Speed: 3.7ms preprocess, 22.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 25.5ms
# Speed: 0.0ms preprocess, 25.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 23.4ms
# Speed: 4.1ms preprocess, 23.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 27.1ms
# Speed: 0.0ms preprocess, 27.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 24.8ms
# Speed: 9.5ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 28.8ms
# Speed: 2.3ms preprocess, 28.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 14.3ms
# Speed: 9.5ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 11.2ms
# Speed: 9.5ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 23 players, 10.7ms
# Speed: 10.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 17.7ms
# Speed: 4.4ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 24 players, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 23 players, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 26 players, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 12.3ms
# Speed: 1.8ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 players, 1 referee, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 players, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 15.3ms
# Speed: 0.4ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
